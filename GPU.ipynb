# %%
# !nvidia-smi
# Out:
# Mon May 11 18:58:14 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 573.22                 Driver Version: 573.22         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5080 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   52C    P0             25W /  130W |     532MiB /  16303MiB |      4%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2084    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A            2264    C+G   ....0.3912.98\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            4372    C+G   ...crosoft\OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A            5708    C+G   ...0.296.3.3\OverwolfBrowser.exe      N/A      |
# |    0   N/A  N/A            6644    C+G   ...8wekyb3d8bbwe\M365Copilot.exe      N/A      |
# |    0   N/A  N/A           11444    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           11720    C+G   ....0.3912.98\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           11780    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           14268    C+G   ...ianxiazaiqu\ToDesk\ToDesk.exe      N/A      |
# |    0   N/A  N/A           15916    C+G   ...ffice6\promecefpluginhost.exe      N/A      |
# |    0   N/A  N/A           28000    C+G   ...s (x86)\Overwolf\Overwolf.exe      N/A      |
# |    0   N/A  N/A           32952    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           34372    C+G   ....0.3912.98\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           35740    C+G   ....0.3912.98\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           36044    C+G   ...25.3.1\jbr\bin\cef_server.exe      N/A      |
# |    0   N/A  N/A           38252    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           42468    C+G   ...4__w2gh52qy24etm\Nahimic3.exe      N/A      |
# |    0   N/A  N/A           61464    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           71748    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           72784    C+G   ....0.3912.98\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           78396    C+G   ...ram Files\Tencent\QQNT\QQ.exe      N/A      |
# |    0   N/A  N/A           81588    C+G   ...m Files\Tencent\QQNT\QQEX.exe      N/A      |
# |    0   N/A  N/A           81696    C+G   ...laude\app-1.6608.2\claude.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
from torch import nn
torch.device('cpu'),torch.device('cuda'),torch.device('cuda:1')
# Out:
# (device(type='cpu'), device(type='cuda'), device(type='cuda', index=1))

# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0+cpu

# %%
torch.cuda.device_count()
# Out:
# 0
